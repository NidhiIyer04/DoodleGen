# %%
# !unzip '/content/drive/MyDrive/doodle_data/cartoonset10k.zip'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: cartoonset10k/cs11130198548099864740.csv
#   inflating: cartoonset10k/cs11130198548099864740.png
#   inflating: cartoonset10k/cs11130522928710913906.csv
#   inflating: cartoonset10k/cs11130522928710913906.png
#   inflating: cartoonset10k/cs11130692035407747496.csv
#   inflating: cartoonset10k/cs11130692035407747496.png
#   inflating: cartoonset10k/cs1113080672465802980.csv
#   inflating: cartoonset10k/cs1113080672465802980.png
#   inflating: cartoonset10k/cs11131138722323947780.csv
#   inflating: cartoonset10k/cs11131138722323947780.png
#   inflating: cartoonset10k/cs1113121412202668922.csv
#   inflating: cartoonset10k/cs1113121412202668922.png
#   inflating: cartoonset10k/cs11131333133753359573.csv
#   inflating: cartoonset10k/cs11131333133753359573.png
#   inflating: cartoonset10k/cs1113143340294813643.csv
#   inflating: cartoonset10k/cs1113143340294813643.png
#   inflating: cartoonset10k/cs11131732994961040179.csv
#   inflating: cartoonset10k/cs11131732994961040179.png
#   inflating: cartoonset10k/cs1113191746674328122.csv
#   inflating: cartoonset10k/cs1113191746674328122.png
#   inflating: cartoonset10k/cs11131958805482037869.csv
#   inflating: cartoonset10k/cs11131958805482037869.png
#   inflating: cartoonset10k/cs1113266829786440678.csv
#   inflating: cartoonset10k/cs1113266829786440678.png
#   inflating: cartoonset10k/cs11132915529795678766.csv
#   inflating: cartoonset10k/cs11132915529795678766.png
#   inflating: cartoonset10k/cs11132936387798059170.csv
#   inflating: cartoonset10k/cs11132936387798059170.png
#   inflating: cartoonset10k/cs11133066143775655628.csv
#   inflating: cartoonset10k/cs11133066143775655628.png
#   inflating: cartoonset10k/cs11133497356480330217.csv
#   inflating: cartoonset10k/cs11133497356480330217.png
#   inflating: cartoonset10k/cs11133867663687743440.csv
#   inflating: cartoonset10k/cs11133867663687743440.png
#   inflating: cartoonset10k/cs11134047720151505197.csv
#   inflating: cartoonset10k/cs11134047720151505197.png
#   inflating: cartoonset10k/cs11134535717464709000.csv
#   inflating: cartoonset10k/cs11134535717464709000.png
#   inflating: cartoonset10k/cs11134753284764628952.csv
#   inflating: cartoonset10k/cs11134753284764628952.png
#   inflating: cartoonset10k/cs1113477999806933290.csv
#   inflating: cartoonset10k/cs1113477999806933290.png
#   inflating: cartoonset10k/cs11134786257215637705.csv
#   inflating: cartoonset10k/cs11134786257215637705.png
#   inflating: cartoonset10k/cs1113496428576681924.csv
#   inflating: cartoonset10k/cs1113496428576681924.png
#   inflating: cartoonset10k/cs11134989093826851425.csv
#   inflating: cartoonset10k/cs11134989093826851425.png
#   inflating: cartoonset10k/cs1113523744969311459.csv
#   inflating: cartoonset10k/cs1113523744969311459.png
#   inflating: cartoonset10k/cs1113538987882690977.csv
#   inflating: cartoonset10k/cs1113538987882690977.png
#   inflating: cartoonset10k/cs11135559879677225217.csv
#   inflating: cartoonset10k/cs11135559879677225217.png
#   inflating: cartoonset10k/cs11135606124320516824.csv
#   inflating: cartoonset10k/cs11135606124320516824.png
#   inflating: cartoonset10k/cs11135735623371502721.csv
#   inflating: cartoonset10k/cs11135735623371502721.png
#   inflating: cartoonset10k/cs11135961484745230025.csv
#   inflating: cartoonset10k/cs11135961484745230025.png
#   inflating: cartoonset10k/cs11136017821382747697.csv
#   inflating: cartoonset10k/cs11136017821382747697.png
#   inflating: cartoonset10k/cs1113606062696038547.csv
#   inflating: cartoonset10k/cs1113606062696038547.png
#   inflating: cartoonset10k/cs11136263251200794916.csv
#   inflating: cartoonset10k/cs11136263251200794916.png
#   inflating: cartoonset10k/cs11136314742610072987.csv
#   inflating: cartoonset10k/cs11136314742610072987.png
#   inflating: cartoonset10k/cs1113644606218828913.csv
#   inflating: cartoonset10k/cs1113644606218828913.png
#   inflating: cartoonset10k/cs11136453119697768637.csv
#   inflating: cartoonset10k/cs11136453119697768637.png
#   inflating: cartoonset10k/cs11136496602601475419.csv
#   inflating: cartoonset10k/cs11136496602601475419.png
#   inflating: cartoonset10k/cs11136860193173317772.csv
#   inflating: cartoonset10k/cs11136860193173317772.png
#   inflating: cartoonset10k/cs11136872291702962442.csv
#   inflating: cartoonset10k/cs11136872291702962442.png
#   inflating: cartoonset10k/cs11137037358414330523.csv
#   inflating: cartoonset10k/cs11137037358414330523.png
#   inflating: cartoonset10k/cs11137050825127185515.csv
#   inflating: cartoonset10k/cs11137050825127185515.png
#   inflating: cartoonset10k/cs11137257358885041395.csv
#   inflating: cartoonset10k/cs11137257358885041395.png
#   inflating: cartoonset10k/cs11137332460465103057.csv
#   inflating: cartoonset10k/cs11137332460465103057.png
#   inflating: cartoonset10k/cs1113769797051614277.csv
#   inflating: cartoonset10k/cs1113769797051614277.png
#   inflating: cartoonset10k/cs11138291360781717539.csv
#   inflating: cartoonset10k/cs11138291360781717539.png
#   inflating: cartoonset10k/cs11138294816592821469.csv
#   inflating: cartoonset10k/cs11138294816592821469.png
#   inflating: cartoonset10k/cs11138394713940700875.csv
#   inflating: cartoonset10k/cs11138394713940700875.png
#   inflating: cartoonset10k/cs11138466041691299446.csv
#   inflating: cartoonset10k/cs11138466041691299446.png
#   inflating: cartoonset10k/cs11138526702977699780.csv
#   inflating: cartoonset10k/cs11138526702977699780.png
#   inflating: cartoonset10k/cs11138575707292704876.csv
#   inflating: cartoonset10k/cs11138575707292704876.png
#   inflating: cartoonset10k/cs11138602779029317623.csv
#   inflating: cartoonset10k/cs11138602779029317623.png
#   inflating: cartoonset10k/cs1113865476978545785.csv
#   inflating: cartoonset10k/cs1113865476978545785.png
#   inflating: cartoonset10k/cs11138795148352425023.csv
#   inflating: cartoonset10k/cs11138795148352425023.png
#   inflating: cartoonset10k/cs11138866308948137715.csv
#   inflating: cartoonset10k/cs11138866308948137715.png
#   inflating: cartoonset10k/cs11138922992416210040.csv
#   inflating: cartoonset10k/cs11138922992416210040.png
#   inflating: cartoonset10k/cs11139400542974454608.csv
#   inflating: cartoonset10k/cs11139400542974454608.png
#   inflating: cartoonset10k/cs11139462015412455458.csv
#   inflating: cartoonset10k/cs11139462015412455458.png
#   inflating: cartoonset10k/cs11139519476278498124.csv
#   inflating: cartoonset10k/cs11139519476278498124.png
#   inflating: cartoonset10k/cs11139589634080314068.csv
#   inflating: cartoonset10k/cs11139589634080314068.png
#   inflating: cartoonset10k/cs11139690210701666226.csv
#   inflating: cartoonset10k/cs11139690210701666226.png
#   inflating: cartoonset10k/cs11139930814171446623.csv
#   inflating: cartoonset10k/cs11139930814171446623.png
#   inflating: cartoonset10k/cs11139943228285846285.csv
#   inflating: cartoonset10k/cs11139943228285846285.png
#   inflating: cartoonset10k/cs11140003658738101322.csv
#   inflating: cartoonset10k/cs11140003658738101322.png
#   inflating: cartoonset10k/cs11140218527540422329.csv
#   inflating: cartoonset10k/cs11140218527540422329.png
#   inflating: cartoonset10k/cs11140427308785419362.csv
#   inflating: cartoonset10k/cs11140427308785419362.png
#   inflating: cartoonset10k/cs11140549185003132717.csv
#   inflating: cartoonset10k/cs11140549185003132717.png
#   inflating: cartoonset10k/cs11140906511598337553.csv
#   inflating: cartoonset10k/cs11140906511598337553.png
#   inflating: cartoonset10k/cs11141298913411658991.csv
#   inflating: cartoonset10k/cs11141298913411658991.png
#   inflating: cartoonset10k/cs11141674401044108108.csv
#   inflating: cartoonset10k/cs11141674401044108108.png
#   inflating: cartoonset10k/cs11141787152551789065.csv
#   inflating: cartoonset10k/cs11141787152551789065.png
#   inflating: cartoonset10k/cs11142005315506897784.csv
#   inflating: cartoonset10k/cs11142005315506897784.png
#   inflating: cartoonset10k/cs11142391806959176800.csv
#   inflating: cartoonset10k/cs11142391806959176800.png
#   inflating: cartoonset10k/cs11142568986880624972.csv
#   inflating: cartoonset10k/cs11142568986880624972.png
#   inflating: cartoonset10k/cs11142603379720130791.csv
#   inflating: cartoonset10k/cs11142603379720130791.png
#   inflating: cartoonset10k/cs11142615110309187142.csv
#   inflating: cartoonset10k/cs11142615110309187142.png
#   inflating: cartoonset10k/cs11142714283978259956.csv
#   inflating: cartoonset10k/cs11142714283978259956.png
#   inflating: cartoonset10k/cs11143046526141630183.csv
#   inflating: cartoonset10k/cs11143046526141630183.png
#   inflating: cartoonset10k/cs1114307367145359759.csv
#   inflating: cartoonset10k/cs1114307367145359759.png
#   inflating: cartoonset10k/cs11143222935634682492.csv
#   inflating: cartoonset10k/cs11143222935634682492.png
#   inflating: cartoonset10k/cs11143641421161678246.csv
#   inflating: cartoonset10k/cs11143641421161678246.png
#   inflating: cartoonset10k/cs11143701097792090988.csv
#   inflating: cartoonset10k/cs11143701097792090988.png
#   inflating: cartoonset10k/cs11144209623292095789.csv
#   inflating: cartoonset10k/cs11144209623292095789.png
#   inflating: cartoonset10k/cs11144438156244547623.csv
#   inflating: cartoonset10k/cs11144438156244547623.png
#   inflating: cartoonset10k/cs11144648534196541680.csv
#   inflating: cartoonset10k/cs11144648534196541680.png
#   inflating: cartoonset10k/cs11144755791561499487.csv
#   inflating: cartoonset10k/cs11144755791561499487.png
#   inflating: cartoonset10k/cs11144771842496822497.csv
#   inflating: cartoonset10k/cs11144771842496822497.png
#   inflating: cartoonset10k/cs11144839232855900270.csv
#   inflating: cartoonset10k/cs11144839232855900270.png
#   inflating: cartoonset10k/cs11145020631123672305.csv
#   inflating: cartoonset10k/cs11145020631123672305.png
#   inflating: cartoonset10k/cs11145111983251089937.csv
#   inflating: cartoonset10k/cs11145111983251089937.png
#   inflating: cartoonset10k/cs11145425306336599278.csv
#   inflating: cartoonset10k/cs11145425306336599278.png
#   inflating: cartoonset10k/cs11145436980026217978.csv
#   inflating: cartoonset10k/cs11145436980026217978.png
#   inflating: cartoonset10k/cs11145488384325164480.csv
#   inflating: cartoonset10k/cs11145488384325164480.png
#   inflating: cartoonset10k/cs11145489068269049669.csv
#   inflating: cartoonset10k/cs11145489068269049669.png
#   inflating: cartoonset10k/cs11145493023054731031.csv
#   inflating: cartoonset10k/cs11145493023054731031.png
#   inflating: cartoonset10k/cs11145582130718590931.csv
#   inflating: cartoonset10k/cs11145582130718590931.png
#   inflating: cartoonset10k/cs11145800234399341722.csv
#   inflating: cartoonset10k/cs11145800234399341722.png
#   inflating: cartoonset10k/cs11145956767234892151.csv
#   inflating: cartoonset10k/cs11145956767234892151.png
#   inflating: cartoonset10k/cs11146066511868532984.csv
#   inflating: cartoonset10k/cs11146066511868532984.png
#   inflating: cartoonset10k/cs11146173440361477050.csv
#   inflating: cartoonset10k/cs11146173440361477050.png
#   inflating: cartoonset10k/cs111464773118169668.csv
#   inflating: cartoonset10k/cs111464773118169668.png
#   inflating: cartoonset10k/cs11146613433427270444.csv
#   inflating: cartoonset10k/cs11146613433427270444.png
#   inflating: cartoonset10k/cs11146989337610204120.csv
#   inflating: cartoonset10k/cs11146989337610204120.png
#   inflating: cartoonset10k/cs11147042896975569572.csv
#   inflating: cartoonset10k/cs11147042896975569572.png
#   inflating: cartoonset10k/cs11147047648987984015.csv
#   inflating: cartoonset10k/cs11147047648987984015.png
#   inflating: cartoonset10k/cs11147080606797371793.csv
#   inflating: cartoonset10k/cs11147080606797371793.png
#   inflating: cartoonset10k/cs11147099153760662954.csv
#   inflating: cartoonset10k/cs11147099153760662954.png
#   inflating: cartoonset10k/cs11147271128118562211.csv
#   inflating: cartoonset10k/cs11147271128118562211.png
#   inflating: cartoonset10k/cs11147303655251324759.csv
#   inflating: cartoonset10k/cs11147303655251324759.png
#   inflating: cartoonset10k/cs11147359840741963476.csv
#   inflating: cartoonset10k/cs11147359840741963476.png
#   inflating: cartoonset10k/cs11147630489700439751.csv
#   inflating: cartoonset10k/cs11147630489700439751.png
#   inflating: cartoonset10k/cs11147705467668562574.csv
#   inflating: cartoonset10k/cs11147705467668562574.png
#   inflating: cartoonset10k/cs1114773155525310197.csv
#   inflating: cartoonset10k/cs1114773155525310197.png
#   inflating: cartoonset10k/cs11147846183443635860.csv
#   inflating: cartoonset10k/cs11147846183443635860.png
#   inflating: cartoonset10k/cs11148076390272955886.csv
#   inflating: cartoonset10k/cs11148076390272955886.png
#   inflating: cartoonset10k/cs11148130963710293998.csv
#   inflating: cartoonset10k/cs11148130963710293998.png
#   inflating: cartoonset10k/cs11148272501951244004.csv
#   inflating: cartoonset10k/cs11148272501951244004.png
#   inflating: cartoonset10k/cs11148275389683769560.csv
#   inflating: cartoonset10k/cs11148275389683769560.png
#   inflating: cartoonset10k/cs11148288373868928307.csv
#   inflating: cartoonset10k/cs11148288373868928307.png
#   inflating: cartoonset10k/cs11148571638049570785.csv
#   inflating: cartoonset10k/cs11148571638049570785.png
#   inflating: cartoonset10k/cs11148614335519734155.csv
#   inflating: cartoonset10k/cs11148614335519734155.png
#   inflating: cartoonset10k/cs11148780511575412923.csv
#   inflating: cartoonset10k/cs11148780511575412923.png
#   inflating: cartoonset10k/cs11148826607227020983.csv
#   inflating: cartoonset10k/cs11148826607227020983.png
#   inflating: cartoonset10k/cs11149333083856701230.csv
#   inflating: cartoonset10k/cs11149333083856701230.png
#   inflating: cartoonset10k/cs11149397663515666858.csv
#   inflating: cartoonset10k/cs11149397663515666858.png
#   inflating: cartoonset10k/cs11149622933482069310.csv
#   inflating: cartoonset10k/cs11149622933482069310.png
#   inflating: cartoonset10k/cs1114969175826073797.csv
#   inflating: cartoonset10k/cs1114969175826073797.png
#   inflating: cartoonset10k/cs11150006532861639274.csv
#   inflating: cartoonset10k/cs11150006532861639274.png
#   inflating: cartoonset10k/cs11150488946505026738.csv
#   inflating: cartoonset10k/cs11150488946505026738.png
#   inflating: cartoonset10k/cs11150711894482941937.csv
#   inflating: cartoonset10k/cs11150711894482941937.png
#   inflating: cartoonset10k/cs1115130442703305710.csv
#   inflating: cartoonset10k/cs1115130442703305710.png
#   inflating: cartoonset10k/cs11151312874489582225.csv
#   inflating: cartoonset10k/cs11151312874489582225.png
#   inflating: cartoonset10k/cs11151346809426742050.csv
#   inflating: cartoonset10k/cs11151346809426742050.png
#   inflating: cartoonset10k/cs11151401817400852619.csv
#   inflating: cartoonset10k/cs11151401817400852619.png
#   inflating: cartoonset10k/cs11151608015949649027.csv
#   inflating: cartoonset10k/cs11151608015949649027.png
#   inflating: cartoonset10k/cs11151848387264422211.csv
#   inflating: cartoonset10k/cs11151848387264422211.png
#   inflating: cartoonset10k/cs11151978938468330636.csv
#   inflating: cartoonset10k/cs11151978938468330636.png
#   inflating: cartoonset10k/cs11152005379725049237.csv
#   inflating: cartoonset10k/cs11152005379725049237.png
#   inflating: cartoonset10k/cs11152164573085232978.csv
#   inflating: cartoonset10k/cs11152164573085232978.png
#   inflating: cartoonset10k/cs11152499414595373578.csv
#   inflating: cartoonset10k/cs11152499414595373578.png
#   inflating: cartoonset10k/cs11152729505161787316.csv
#   inflating: cartoonset10k/cs11152729505161787316.png
#   inflating: cartoonset10k/cs11152792067825778964.csv
#   inflating: cartoonset10k/cs11152792067825778964.png
#   inflating: cartoonset10k/cs11153053244694004017.csv
#   inflating: cartoonset10k/cs11153053244694004017.png
#   inflating: cartoonset10k/cs11153951803968908136.csv
#   inflating: cartoonset10k/cs11153951803968908136.png
#   inflating: cartoonset10k/cs11153972240742354155.csv
#   inflating: cartoonset10k/cs11153972240742354155.png
#   inflating: cartoonset10k/cs11154023179505745747.csv
#   inflating: cartoonset10k/cs11154023179505745747.png
#   inflating: cartoonset10k/cs11154204335596910134.csv
#   inflating: cartoonset10k/cs11154204335596910134.png
#   inflating: cartoonset10k/cs1115423080377502943.csv
#   inflating: cartoonset10k/cs1115423080377502943.png
#   inflating: cartoonset10k/cs11154313357950053321.csv
#   inflating: cartoonset10k/cs11154313357950053321.png
#   inflating: cartoonset10k/cs11154329126285700735.csv
#   inflating: cartoonset10k/cs11154329126285700735.png
#   inflating: cartoonset10k/cs11154421730509036242.csv
#   inflating: cartoonset10k/cs11154421730509036242.png
#   inflating: cartoonset10k/cs11154500927757362992.csv
#   inflating: cartoonset10k/cs11154500927757362992.png
#   inflating: cartoonset10k/cs11154562160598083625.csv
#   inflating: cartoonset10k/cs11154562160598083625.png
#   inflating: cartoonset10k/cs11154891926103711212.csv
#   inflating: cartoonset10k/cs11154891926103711212.png
#   inflating: cartoonset10k/cs11154938282067316821.csv
#   inflating: cartoonset10k/cs11154938282067316821.png
#   inflating: cartoonset10k/cs11155008765790395095.csv
#   inflating: cartoonset10k/cs11155008765790395095.png
#   inflating: cartoonset10k/cs11155080062870031301.csv
#   inflating: cartoonset10k/cs11155080062870031301.png
#   inflating: cartoonset10k/cs11155100369087751730.csv
#   inflating: cartoonset10k/cs11155100369087751730.png
#   inflating: cartoonset10k/cs11155181395734564941.csv
#   inflating: cartoonset10k/cs11155181395734564941.png
#   inflating: cartoonset10k/cs11155234045428151424.csv
#   inflating: cartoonset10k/cs11155234045428151424.png
#   inflating: cartoonset10k/cs11155469459819570851.csv
#   inflating: cartoonset10k/cs11155469459819570851.png
#   inflating: cartoonset10k/cs11155815064920777272.csv
#   inflating: cartoonset10k/cs11155815064920777272.png
#   inflating: cartoonset10k/cs11156130199609761208.csv
#   inflating: cartoonset10k/cs11156130199609761208.png
#   inflating: cartoonset10k/cs11156541039696670166.csv
#   inflating: cartoonset10k/cs11156541039696670166.png
#   inflating: cartoonset10k/cs11156656892869349248.csv
#   inflating: cartoonset10k/cs11156656892869349248.png
#   inflating: cartoonset10k/cs11156968266978706264.csv
#   inflating: cartoonset10k/cs11156968266978706264.png
#   inflating: cartoonset10k/cs11157066228214030694.csv
#   inflating: cartoonset10k/cs11157066228214030694.png
#   inflating: cartoonset10k/cs11157267954282814274.csv
#   inflating: cartoonset10k/cs11157267954282814274.png
#   inflating: cartoonset10k/cs11157667341935180945.csv
#   inflating: cartoonset10k/cs11157667341935180945.png
#   inflating: cartoonset10k/cs11158142254297944292.csv
#   inflating: cartoonset10k/cs11158142254297944292.png
#   inflating: cartoonset10k/cs11158146223056161638.csv
#   inflating: cartoonset10k/cs11158146223056161638.png
#   inflating: cartoonset10k/cs11158387921629854258.csv
#   inflating: cartoonset10k/cs11158387921629854258.png
#   inflating: cartoonset10k/cs11158410342378937178.csv
#   inflating: cartoonset10k/cs11158410342378937178.png
#   inflating: cartoonset10k/cs11158501045424176310.csv
#   inflating: cartoonset10k/cs11158501045424176310.png
#   inflating: cartoonset10k/cs11158657597892378976.csv
#   inflating: cartoonset10k/cs11158657597892378976.png
#   inflating: cartoonset10k/cs11159298448432933639.csv
#   inflating: cartoonset10k/cs11159298448432933639.png
#   inflating: cartoonset10k/cs1115946897994627264.csv
#   inflating: cartoonset10k/cs1115946897994627264.png
#   inflating: cartoonset10k/cs11159548273130563255.csv
#   inflating: cartoonset10k/cs11159548273130563255.png
#   inflating: cartoonset10k/cs11159614780639352659.csv
#   inflating: cartoonset10k/cs11159614780639352659.png
#   inflating: cartoonset10k/cs11159626338146302946.csv
#   inflating: cartoonset10k/cs11159626338146302946.png
#   inflating: cartoonset10k/cs11159789558392698002.csv
#   inflating: cartoonset10k/cs11159789558392698002.png
#   inflating: cartoonset10k/cs11159809880169449963.csv
#   inflating: cartoonset10k/cs11159809880169449963.png
#   inflating: cartoonset10k/cs11159983853684089662.csv
#   inflating: cartoonset10k/cs11159983853684089662.png
#   inflating: cartoonset10k/cs11159986392738798135.csv
#   inflating: cartoonset10k/cs11159986392738798135.png
#   inflating: cartoonset10k/cs11160231514344235951.csv
#   inflating: cartoonset10k/cs11160231514344235951.png
#   inflating: cartoonset10k/cs11160314280556986046.csv
#   inflating: cartoonset10k/cs11160314280556986046.png
#   inflating: cartoonset10k/cs1116047889796927240.csv
#   inflating: cartoonset10k/cs1116047889796927240.png
#   inflating: cartoonset10k/cs11160648174136957928.csv
#   inflating: cartoonset10k/cs11160648174136957928.png
#   inflating: cartoonset10k/cs11161326305119369363.csv
#   inflating: cartoonset10k/cs11161326305119369363.png
#   inflating: cartoonset10k/cs11161331570407760362.csv
#   inflating: cartoonset10k/cs11161331570407760362.png
#   inflating: cartoonset10k/cs11161369553718017557.csv
#   inflating: cartoonset10k/cs11161369553718017557.png
#   inflating: cartoonset10k/cs11161376072509279489.csv
#   inflating: cartoonset10k/cs11161376072509279489.png
#   inflating: cartoonset10k/cs11161423433873210246.csv
#   inflating: cartoonset10k/cs11161423433873210246.png
#   inflating: cartoonset10k/cs11161624487220755146.csv
#   inflating: cartoonset10k/cs11161624487220755146.png
#   inflating: cartoonset10k/cs11161946795925325318.csv
#   inflating: cartoonset10k/cs11161946795925325318.png
#   inflating: cartoonset10k/cs11161947717192955750.csv
#   inflating: cartoonset10k/cs11161947717192955750.png
#   inflating: cartoonset10k/cs11161969148654385985.csv
#   inflating: cartoonset10k/cs11161969148654385985.png
#   inflating: cartoonset10k/cs11161981790321373846.csv
#   inflating: cartoonset10k/cs11161981790321373846.png
#   inflating: cartoonset10k/cs11162005297798346949.csv
#   inflating: cartoonset10k/cs11162005297798346949.png
#   inflating: cartoonset10k/cs11162097515499706284.csv
#   inflating: cartoonset10k/cs11162097515499706284.png
#   inflating: cartoonset10k/cs11162185513908242757.csv
#   inflating: cartoonset10k/cs11162185513908242757.png
#   inflating: cartoonset10k/cs11162738753130950229.csv
#   inflating: cartoonset10k/cs11162738753130950229.png
#   inflating: cartoonset10k/cs11163359929310046273.csv
#   inflating: cartoonset10k/cs11163359929310046273.png
#   inflating: cartoonset10k/cs11164161632030785870.csv
#   inflating: cartoonset10k/cs11164161632030785870.png
#   inflating: cartoonset10k/cs1116425016637257150.csv
#   inflating: cartoonset10k/cs1116425016637257150.png
#   inflating: cartoonset10k/cs11164273269605625623.csv
#   inflating: cartoonset10k/cs11164273269605625623.png
#   inflating: cartoonset10k/cs1116467791769138795.csv
#   inflating: cartoonset10k/cs1116467791769138795.png
#   inflating: cartoonset10k/cs11164772183598071343.csv
#   inflating: cartoonset10k/cs11164772183598071343.png
#   inflating: cartoonset10k/cs11164844425400224576.csv
#   inflating: cartoonset10k/cs11164844425400224576.png
#   inflating: cartoonset10k/cs11164912184698224830.csv
#   inflating: cartoonset10k/cs11164912184698224830.png
#   inflating: cartoonset10k/cs11165736394829153033.csv
#   inflating: cartoonset10k/cs11165736394829153033.png
#   inflating: cartoonset10k/cs11165775737705696622.csv
#   inflating: cartoonset10k/cs11165775737705696622.png
#   inflating: cartoonset10k/cs11166023647623864950.csv
#   inflating: cartoonset10k/cs11166023647623864950.png
#   inflating: cartoonset10k/cs11166058282140336995.csv
#   inflating: cartoonset10k/cs11166058282140336995.png
#   inflating: cartoonset10k/cs11166081050910845403.csv
#   inflating: cartoonset10k/cs11166081050910845403.png
#   inflating: cartoonset10k/cs11166245004617899506.csv
#   inflating: cartoonset10k/cs11166245004617899506.png
#   inflating: cartoonset10k/cs11166532282712066902.csv
#   inflating: cartoonset10k/cs11166532282712066902.png
#   inflating: cartoonset10k/cs11166738707192333276.csv
#   inflating: cartoonset10k/cs11166738707192333276.png
#   inflating: cartoonset10k/cs11167030115785929302.csv
#   inflating: cartoonset10k/cs11167030115785929302.png
#   inflating: cartoonset10k/cs11167046543704449829.csv
#   inflating: cartoonset10k/cs11167046543704449829.png
#   inflating: cartoonset10k/cs11167246413358112990.csv
#   inflating: cartoonset10k/cs11167246413358112990.png
#   inflating: cartoonset10k/cs11167250507161636636.csv
#   inflating: cartoonset10k/cs11167250507161636636.png
#   inflating: cartoonset10k/cs11167348011493044307.csv
#   inflating: cartoonset10k/cs11167348011493044307.png
#   inflating: cartoonset10k/cs11167486060275177943.csv
#   inflating: cartoonset10k/cs11167486060275177943.png
#   inflating: cartoonset10k/cs11167490781471735738.csv
#   inflating: cartoonset10k/cs11167490781471735738.png
#   inflating: cartoonset10k/cs11167948087917660714.csv
#   inflating: cartoonset10k/cs11167948087917660714.png
#   inflating: cartoonset10k/cs11168012429038215627.csv
#   inflating: cartoonset10k/cs11168012429038215627.png
#   inflating: cartoonset10k/cs11168121247997708342.csv
#   inflating: cartoonset10k/cs11168121247997708342.png
#   inflating: cartoonset10k/cs11168223410612700146.csv
#   inflating: cartoonset10k/cs11168223410612700146.png
#   inflating: cartoonset10k/cs11168235775444793259.csv
#   inflating: cartoonset10k/cs11168235775444793259.png
#   inflating: cartoonset10k/cs11168513874556348577.csv
#   inflating: cartoonset10k/cs11168513874556348577.png
#   inflating: cartoonset10k/cs1116857428806856602.csv
#   inflating: cartoonset10k/cs1116857428806856602.png
#   inflating: cartoonset10k/cs11169225825407366986.csv
#   inflating: cartoonset10k/cs11169225825407366986.png
#   inflating: cartoonset10k/cs11169372710865321421.csv
#   inflating: cartoonset10k/cs11169372710865321421.png
#   inflating: cartoonset10k/cs11169434009247213707.csv
#   inflating: cartoonset10k/cs11169434009247213707.png
#   inflating: cartoonset10k/cs11169539706056107824.csv
#   inflating: cartoonset10k/cs11169539706056107824.png
#   inflating: cartoonset10k/cs11169778992462784865.csv
#   inflating: cartoonset10k/cs11169778992462784865.png
#   inflating: cartoonset10k/cs11169800541779330059.csv
#   inflating: cartoonset10k/cs11169800541779330059.png
#   inflating: cartoonset10k/cs11169912891482826114.csv
#   inflating: cartoonset10k/cs11169912891482826114.png
#   inflating: cartoonset10k/cs11170086329906027141.csv
#   inflating: cartoonset10k/cs11170086329906027141.png
#   inflating: cartoonset10k/cs11170147179413743228.csv
#   inflating: cartoonset10k/cs11170147179413743228.png
#   inflating: cartoonset10k/cs11170175319870418451.csv
#   inflating: cartoonset10k/cs11170175319870418451.png
#   inflating: cartoonset10k/cs11170294188193849361.csv
#   inflating: cartoonset10k/cs11170294188193849361.png
#   inflating: cartoonset10k/cs11170577314332125202.csv
#   inflating: cartoonset10k/cs11170577314332125202.png
#   inflating: cartoonset10k/cs11170633694117073853.csv
#   inflating: cartoonset10k/cs11170633694117073853.png
#   inflating: cartoonset10k/cs11171009309190314808.csv
#   inflating: cartoonset10k/cs11171009309190314808.png
#   inflating: cartoonset10k/cs11171075486337322849.csv
#   inflating: cartoonset10k/cs11171075486337322849.png
#   inflating: cartoonset10k/cs11171207964296302868.csv
#   inflating: cartoonset10k/cs11171207964296302868.png
#   inflating: cartoonset10k/cs1117122096399730519.csv
#   inflating: cartoonset10k/cs1117122096399730519.png
#   inflating: cartoonset10k/cs11171592883821782190.csv
#   inflating: cartoonset10k/cs11171592883821782190.png
#   inflating: cartoonset10k/cs11171655708744286970.csv
#   inflating: cartoonset10k/cs11171655708744286970.png
#   inflating: cartoonset10k/cs1117169805628754546.csv
#   inflating: cartoonset10k/cs1117169805628754546.png
#   inflating: cartoonset10k/cs11171781168471737646.csv
#   inflating: cartoonset10k/cs11171781168471737646.png
#   inflating: cartoonset10k/cs11171979812199652435.csv
#   inflating: cartoonset10k/cs11171979812199652435.png
#   inflating: cartoonset10k/cs11172239442668408745.csv
#   inflating: cartoonset10k/cs11172239442668408745.png
#   inflating: cartoonset10k/cs11172269624394190908.csv
#   inflating: cartoonset10k/cs11172269624394190908.png
#   inflating: cartoonset10k/cs11172335889800201814.csv
#   inflating: cartoonset10k/cs11172335889800201814.png
#   inflating: cartoonset10k/cs11172342731392211264.csv
#   inflating: cartoonset10k/cs11172342731392211264.png
#   inflating: cartoonset10k/cs11172649277136586935.csv
#   inflating: cartoonset10k/cs11172649277136586935.png
#   inflating: cartoonset10k/cs11172721407973858827.csv
#   inflating: cartoonset10k/cs11172721407973858827.png
#   inflating: cartoonset10k/cs11172940949811352031.csv
#   inflating: cartoonset10k/cs11172940949811352031.png
#   inflating: cartoonset10k/cs11172942876500100890.csv
#   inflating: cartoonset10k/cs11172942876500100890.png
#   inflating: cartoonset10k/cs11173001461653885566.csv
#   inflating: cartoonset10k/cs11173001461653885566.png
#   inflating: cartoonset10k/cs111730397949486489.csv
#   inflating: cartoonset10k/cs111730397949486489.png
#   inflating: cartoonset10k/cs11173042621249210969.csv
#   inflating: cartoonset10k/cs11173042621249210969.png
#   inflating: cartoonset10k/cs11173466591710808595.csv
#   inflating: cartoonset10k/cs11173466591710808595.png
#   inflating: cartoonset10k/cs1117348771948491202.csv
#   inflating: cartoonset10k/cs1117348771948491202.png
#   inflating: cartoonset10k/cs11173494137390545549.csv
#   inflating: cartoonset10k/cs11173494137390545549.png
#   inflating: cartoonset10k/cs11173568267500739501.csv
#   inflating: cartoonset10k/cs11173568267500739501.png
#   inflating: cartoonset10k/cs11174231616860171780.csv
#   inflating: cartoonset10k/cs11174231616860171780.png
#   inflating: cartoonset10k/cs11174250030640403401.csv
#   inflating: cartoonset10k/cs11174250030640403401.png
#   inflating: cartoonset10k/cs11174613028643441900.csv
#   inflating: cartoonset10k/cs11174613028643441900.png
#   inflating: cartoonset10k/cs11174863831972022060.csv
#   inflating: cartoonset10k/cs11174863831972022060.png
#   inflating: cartoonset10k/cs1117490177530247032.csv
#   inflating: cartoonset10k/cs1117490177530247032.png
#   inflating: cartoonset10k/cs11175053207170879914.csv
#   inflating: cartoonset10k/cs11175053207170879914.png
#   inflating: cartoonset10k/cs11175473680233949618.csv
#   inflating: cartoonset10k/cs11175473680233949618.png
#   inflating: cartoonset10k/cs11175658295450907151.csv
#   inflating: cartoonset10k/cs11175658295450907151.png
#   inflating: cartoonset10k/cs11175678803328981487.csv
#   inflating: cartoonset10k/cs11175678803328981487.png
#   inflating: cartoonset10k/cs11175776959614680892.csv
#   inflating: cartoonset10k/cs11175776959614680892.png
#   inflating: cartoonset10k/cs11176104707062367404.csv
#   inflating: cartoonset10k/cs11176104707062367404.png
#   inflating: cartoonset10k/cs11176186124906589960.csv
#   inflating: cartoonset10k/cs11176186124906589960.png
#   inflating: cartoonset10k/cs1117634961629162864.csv
#   inflating: cartoonset10k/cs1117634961629162864.png
#   inflating: cartoonset10k/cs11176601286595187442.csv
#   inflating: cartoonset10k/cs11176601286595187442.png
#   inflating: cartoonset10k/cs11176627781121119892.csv
#   inflating: cartoonset10k/cs11176627781121119892.png
#   inflating: cartoonset10k/cs11176683337725869353.csv
#   inflating: cartoonset10k/cs11176683337725869353.png
#   inflating: cartoonset10k/cs11176932782863573780.csv
#   inflating: cartoonset10k/cs11176932782863573780.png
#   inflating: cartoonset10k/cs11176939038816978925.csv
#   inflating: cartoonset10k/cs11176939038816978925.png
#   inflating: cartoonset10k/cs11176971101305724171.csv
#   inflating: cartoonset10k/cs11176971101305724171.png
#   inflating: cartoonset10k/cs11177080907476040567.csv
#   inflating: cartoonset10k/cs11177080907476040567.png
#   inflating: cartoonset10k/cs11177388183705768839.csv
#   inflating: cartoonset10k/cs11177388183705768839.png
#   inflating: cartoonset10k/cs11177496203350823283.csv
#   inflating: cartoonset10k/cs11177496203350823283.png
#   inflating: cartoonset10k/cs11177537280105403231.csv
#   inflating: cartoonset10k/cs11177537280105403231.png
#   inflating: cartoonset10k/cs11177694188813087954.csv
#   inflating: cartoonset10k/cs11177694188813087954.png
#   inflating: cartoonset10k/cs11177841294462054124.csv
#   inflating: cartoonset10k/cs11177841294462054124.png
#   inflating: cartoonset10k/cs11178336740176879122.csv
#   inflating: cartoonset10k/cs11178336740176879122.png
#   inflating: cartoonset10k/cs1117875714814208424.csv
#   inflating: cartoonset10k/cs1117875714814208424.png
#   inflating: cartoonset10k/cs11178884820552917847.csv
#   inflating: cartoonset10k/cs11178884820552917847.png
#   inflating: cartoonset10k/cs11179000609981509807.csv
#   inflating: cartoonset10k/cs11179000609981509807.png
#   inflating: cartoonset10k/cs11179312144674873261.csv
#   inflating: cartoonset10k/cs11179312144674873261.png
#   inflating: cartoonset10k/cs11179384434923036988.csv
#   inflating: cartoonset10k/cs11179384434923036988.png
#   inflating: cartoonset10k/cs11179570611693693911.csv
#   inflating: cartoonset10k/cs11179570611693693911.png
#   inflating: cartoonset10k/cs11179798371307600145.csv
#   inflating: cartoonset10k/cs11179798371307600145.png
#   inflating: cartoonset10k/cs11180014585012796791.csv
#   inflating: cartoonset10k/cs11180014585012796791.png
#   inflating: cartoonset10k/cs1118009208704102762.csv
#   inflating: cartoonset10k/cs1118009208704102762.png
#   inflating: cartoonset10k/cs11180124488473557868.csv
#   inflating: cartoonset10k/cs11180124488473557868.png
#   inflating: cartoonset10k/cs11180241657536749248.csv
#   inflating: cartoonset10k/cs11180241657536749248.png
#   inflating: cartoonset10k/cs11180264183806398518.csv
#   inflating: cartoonset10k/cs11180264183806398518.png
#   inflating: cartoonset10k/cs11180376374616185307.csv
#   inflating: cartoonset10k/cs11180376374616185307.png
#   inflating: cartoonset10k/cs11180531985378076192.csv
#   inflating: cartoonset10k/cs11180531985378076192.png
#   inflating: cartoonset10k/cs11180625649453176846.csv
#   inflating: cartoonset10k/cs11180625649453176846.png
#   inflating: cartoonset10k/cs11180732484485091593.csv
#   inflating: cartoonset10k/cs11180732484485091593.png
#   inflating: cartoonset10k/cs11181046708023239002.csv
#   inflating: cartoonset10k/cs11181046708023239002.png
#   inflating: cartoonset10k/cs11181049979553052491.csv
#   inflating: cartoonset10k/cs11181049979553052491.png
#   inflating: cartoonset10k/cs11181220725395272424.csv
#   inflating: cartoonset10k/cs11181220725395272424.png
#   inflating: cartoonset10k/cs11181282546989280932.csv
#   inflating: cartoonset10k/cs11181282546989280932.png
#   inflating: cartoonset10k/cs11181294981925549002.csv
#   inflating: cartoonset10k/cs11181294981925549002.png
#   inflating: cartoonset10k/cs11181323143512404358.csv
#   inflating: cartoonset10k/cs11181323143512404358.png
#   inflating: cartoonset10k/cs11181337194905458999.csv
#   inflating: cartoonset10k/cs11181337194905458999.png
#   inflating: cartoonset10k/cs11181344431733103084.csv
#   inflating: cartoonset10k/cs11181344431733103084.png
#   inflating: cartoonset10k/cs11181540535591288784.csv
#   inflating: cartoonset10k/cs11181540535591288784.png
#   inflating: cartoonset10k/cs11181552073127112474.csv
#   inflating: cartoonset10k/cs11181552073127112474.png
#   inflating: cartoonset10k/cs11181552517966404172.csv
#   inflating: cartoonset10k/cs11181552517966404172.png
#   inflating: cartoonset10k/cs11181606153853973214.csv
#   inflating: cartoonset10k/cs11181606153853973214.png
#   inflating: cartoonset10k/cs1118174184925773732.csv
#   inflating: cartoonset10k/cs1118174184925773732.png
#   inflating: cartoonset10k/cs11181787987143249234.csv
#   inflating: cartoonset10k/cs11181787987143249234.png
#   inflating: cartoonset10k/cs11181961635661964552.csv
#   inflating: cartoonset10k/cs11181961635661964552.png
#   inflating: cartoonset10k/cs11182153400467717377.csv
#   inflating: cartoonset10k/cs11182153400467717377.png
#   inflating: cartoonset10k/cs11182395020543251943.csv
#   inflating: cartoonset10k/cs11182395020543251943.png
#   inflating: cartoonset10k/cs11182417325879361040.csv
#   inflating: cartoonset10k/cs11182417325879361040.png
#   inflating: cartoonset10k/cs11182457972974096923.csv
#   inflating: cartoonset10k/cs11182457972974096923.png
#   inflating: cartoonset10k/cs11182486249637528496.csv
#   inflating: cartoonset10k/cs11182486249637528496.png
#   inflating: cartoonset10k/cs11182487729525676050.csv
#   inflating: cartoonset10k/cs11182487729525676050.png
#   inflating: cartoonset10k/cs1118259498584594405.csv
#   inflating: cartoonset10k/cs1118259498584594405.png
#   inflating: cartoonset10k/cs11182602566752278020.csv
#   inflating: cartoonset10k/cs11182602566752278020.png
#   inflating: cartoonset10k/cs11182753918741163335.csv
#   inflating: cartoonset10k/cs11182753918741163335.png
#   inflating: cartoonset10k/cs11183036781343124553.csv
#   inflating: cartoonset10k/cs11183036781343124553.png
#   inflating: cartoonset10k/cs11183146375700363284.csv
#   inflating: cartoonset10k/cs11183146375700363284.png
#   inflating: cartoonset10k/cs11183366667384586539.csv
#   inflating: cartoonset10k/cs11183366667384586539.png
#   inflating: cartoonset10k/cs11183441500215972374.csv
#   inflating: cartoonset10k/cs11183441500215972374.png
#   inflating: cartoonset10k/cs11183550991347970189.csv
#   inflating: cartoonset10k/cs11183550991347970189.png
#   inflating: cartoonset10k/cs11183916032591583923.csv
#   inflating: cartoonset10k/cs11183916032591583923.png
#   inflating: cartoonset10k/cs11184044880230751894.csv
#   inflating: cartoonset10k/cs11184044880230751894.png
#   inflating: cartoonset10k/cs11184311269479975282.csv
#   inflating: cartoonset10k/cs11184311269479975282.png
#   inflating: cartoonset10k/cs11184555116874288823.csv
#   inflating: cartoonset10k/cs11184555116874288823.png
#   inflating: cartoonset10k/cs11184565434537587871.csv
#   inflating: cartoonset10k/cs11184565434537587871.png
#   inflating: cartoonset10k/cs11184630326828509810.csv
#   inflating: cartoonset10k/cs11184630326828509810.png
#   inflating: cartoonset10k/cs11184704358356780033.csv
#   inflating: cartoonset10k/cs11184704358356780033.png
#   inflating: cartoonset10k/cs11184773684531164436.csv
#   inflating: cartoonset10k/cs11184773684531164436.png
#   inflating: cartoonset10k/cs11184826494895115400.csv
#   inflating: cartoonset10k/cs11184826494895115400.png
#   inflating: cartoonset10k/cs11184892240755525295.csv
#   inflating: cartoonset10k/cs11184892240755525295.png
#   inflating: cartoonset10k/cs11184995075532040782.csv
#   inflating: cartoonset10k/cs11184995075532040782.png
#   inflating: cartoonset10k/cs11185054051014512018.csv
#   inflating: cartoonset10k/cs11185054051014512018.png
#   inflating: cartoonset10k/cs11185062103324184649.csv
#   inflating: cartoonset10k/cs11185062103324184649.png
#   inflating: cartoonset10k/cs11185120066334161047.csv
#   inflating: cartoonset10k/cs11185120066334161047.png
#   inflating: cartoonset10k/cs11185194870946741452.csv
#   inflating: cartoonset10k/cs11185194870946741452.png
#   inflating: cartoonset10k/cs11185271079719213405.csv
#   inflating: cartoonset10k/cs11185271079719213405.png
#   inflating: cartoonset10k/cs11185455232041007307.csv
#   inflating: cartoonset10k/cs11185455232041007307.png
#   inflating: cartoonset10k/cs11185563303120156774.csv
#   inflating: cartoonset10k/cs11185563303120156774.png
#   inflating: cartoonset10k/cs11185629159100550613.csv
#   inflating: cartoonset10k/cs11185629159100550613.png
#   inflating: cartoonset10k/cs11185638915518692985.csv
#   inflating: cartoonset10k/cs11185638915518692985.png
#   inflating: cartoonset10k/cs11186715980149394469.csv
#   inflating: cartoonset10k/cs11186715980149394469.png
#   inflating: cartoonset10k/cs11186971255946146154.csv
#   inflating: cartoonset10k/cs11186971255946146154.png
#   inflating: cartoonset10k/cs11187044420317593078.csv
#   inflating: cartoonset10k/cs11187044420317593078.png
#   inflating: cartoonset10k/cs11187054955442377102.csv
#   inflating: cartoonset10k/cs11187054955442377102.png
#   inflating: cartoonset10k/cs11187286711403705549.csv
#   inflating: cartoonset10k/cs11187286711403705549.png
#   inflating: cartoonset10k/cs11187480135739761231.csv
#   inflating: cartoonset10k/cs11187480135739761231.png
#   inflating: cartoonset10k/cs11187501974453575912.csv
#   inflating: cartoonset10k/cs11187501974453575912.png
#   inflating: cartoonset10k/cs11187770152403168828.csv
#   inflating: cartoonset10k/cs11187770152403168828.png
#   inflating: cartoonset10k/cs11187907180283448625.csv
#   inflating: cartoonset10k/cs11187907180283448625.png
#   inflating: cartoonset10k/cs11187908358974038866.csv
#   inflating: cartoonset10k/cs11187908358974038866.png
#   inflating: cartoonset10k/cs11188104994788125027.csv
#   inflating: cartoonset10k/cs11188104994788125027.png
#   inflating: cartoonset10k/cs11188412399428292019.csv
#   inflating: cartoonset10k/cs11188412399428292019.png
#   inflating: cartoonset10k/cs11188484494591628467.csv
#   inflating: cartoonset10k/cs11188484494591628467.png
#   inflating: cartoonset10k/cs1118872693109695646.csv
#   inflating: cartoonset10k/cs1118872693109695646.png
#   inflating: cartoonset10k/cs11188795135194818986.csv
#   inflating: cartoonset10k/cs11188795135194818986.png
#   inflating: cartoonset10k/cs11188840698086204219.csv
#   inflating: cartoonset10k/cs11188840698086204219.png
#   inflating: cartoonset10k/cs11189003965941384915.csv
#   inflating: cartoonset10k/cs11189003965941384915.png
#   inflating: cartoonset10k/cs11189159373392878181.csv
#   inflating: cartoonset10k/cs11189159373392878181.png
#   inflating: cartoonset10k/cs11189295765862756494.csv
#   inflating: cartoonset10k/cs11189295765862756494.png
#   inflating: cartoonset10k/cs11189607539098115306.csv
#   inflating: cartoonset10k/cs11189607539098115306.png
#   inflating: cartoonset10k/cs11189627895711152371.csv
#   inflating: cartoonset10k/cs11189627895711152371.png
#   inflating: cartoonset10k/cs1118967538109468241.csv
#   inflating: cartoonset10k/cs1118967538109468241.png
#   inflating: cartoonset10k/cs11189954782154526462.csv
#   inflating: cartoonset10k/cs11189954782154526462.png
#   inflating: cartoonset10k/cs11190103678621549111.csv
#   inflating: cartoonset10k/cs11190103678621549111.png
#   inflating: cartoonset10k/cs11190144552908123069.csv
#   inflating: cartoonset10k/cs11190144552908123069.png
#   inflating: cartoonset10k/cs11190176825719091808.csv
#   inflating: cartoonset10k/cs11190176825719091808.png
#   inflating: cartoonset10k/cs11190715996089685533.csv
#   inflating: cartoonset10k/cs11190715996089685533.png
#   inflating: cartoonset10k/cs11190810491602496579.csv
#   inflating: cartoonset10k/cs11190810491602496579.png
#   inflating: cartoonset10k/cs11191067375003179661.csv
#   inflating: cartoonset10k/cs11191067375003179661.png
#   inflating: cartoonset10k/cs11191078014077684224.csv
#   inflating: cartoonset10k/cs11191078014077684224.png
#   inflating: cartoonset10k/cs11191558220740573170.csv
#   inflating: cartoonset10k/cs11191558220740573170.png
#   inflating: cartoonset10k/cs11191661473236624418.csv
#   inflating: cartoonset10k/cs11191661473236624418.png
#   inflating: cartoonset10k/cs1119171763836685897.csv
#   inflating: cartoonset10k/cs1119171763836685897.png
#   inflating: cartoonset10k/cs11191756085011977499.csv
#   inflating: cartoonset10k/cs11191756085011977499.png
#   inflating: cartoonset10k/cs11191769028225830797.csv
#   inflating: cartoonset10k/cs11191769028225830797.png
#   inflating: cartoonset10k/cs1119190753520932026.csv
#   inflating: cartoonset10k/cs1119190753520932026.png
#   inflating: cartoonset10k/cs11191967558800299748.csv
#   inflating: cartoonset10k/cs11191967558800299748.png
#   inflating: cartoonset10k/cs11191997005041131398.csv
#   inflating: cartoonset10k/cs11191997005041131398.png
#   inflating: cartoonset10k/cs1119201330465510305.csv
#   inflating: cartoonset10k/cs1119201330465510305.png
#   inflating: cartoonset10k/cs11192087289415991288.csv
#   inflating: cartoonset10k/cs11192087289415991288.png
#   inflating: cartoonset10k/cs11192220322581654620.csv
#   inflating: cartoonset10k/cs11192220322581654620.png
#   inflating: cartoonset10k/cs1119228376718142899.csv
#   inflating: cartoonset10k/cs1119228376718142899.png
#   inflating: cartoonset10k/cs11192951986834061678.csv
#   inflating: cartoonset10k/cs11192951986834061678.png
#   inflating: cartoonset10k/cs11193029175846081015.csv
#   inflating: cartoonset10k/cs11193029175846081015.png
#   inflating: cartoonset10k/cs11193360582897282341.csv
#   inflating: cartoonset10k/cs11193360582897282341.png
#   inflating: cartoonset10k/cs11193541851502641344.csv
#   inflating: cartoonset10k/cs11193541851502641344.png
#   inflating: cartoonset10k/cs11193614756759263657.csv
#   inflating: cartoonset10k/cs11193614756759263657.png
#   inflating: cartoonset10k/cs11193923144708002845.csv
#   inflating: cartoonset10k/cs11193923144708002845.png
#   inflating: cartoonset10k/cs11194151689303703145.csv
#   inflating: cartoonset10k/cs11194151689303703145.png
#   inflating: cartoonset10k/cs11194411896797828123.csv
#   inflating: cartoonset10k/cs11194411896797828123.png
#   inflating: cartoonset10k/cs11194529339394401190.csv
#   inflating: cartoonset10k/cs11194529339394401190.png
#   inflating: cartoonset10k/cs11194728037731636091.csv
#   inflating: cartoonset10k/cs11194728037731636091.png
#   inflating: cartoonset10k/cs11194779966928068909.csv
#   inflating: cartoonset10k/cs11194779966928068909.png
#   inflating: cartoonset10k/cs11194818564811502252.csv
#   inflating: cartoonset10k/cs11194818564811502252.png
#   inflating: cartoonset10k/cs11194965263667867057.csv
#   inflating: cartoonset10k/cs11194965263667867057.png
#   inflating: cartoonset10k/cs11194989346555312081.csv
#   inflating: cartoonset10k/cs11194989346555312081.png
#   inflating: cartoonset10k/cs11195068835968144765.csv
#   inflating: cartoonset10k/cs11195068835968144765.png
#   inflating: cartoonset10k/cs11195654900738026747.csv
#   inflating: cartoonset10k/cs11195654900738026747.png
#   inflating: cartoonset10k/cs11195803525581833743.csv
#   inflating: cartoonset10k/cs11195803525581833743.png
#   inflating: cartoonset10k/cs1119611676536276135.csv
#   inflating: cartoonset10k/cs1119611676536276135.png
#   inflating: cartoonset10k/cs11196185307665378032.csv
#   inflating: cartoonset10k/cs11196185307665378032.png
#   inflating: cartoonset10k/cs11196195788828629231.csv
#   inflating: cartoonset10k/cs11196195788828629231.png
#   inflating: cartoonset10k/cs11196641812406231260.csv
#   inflating: cartoonset10k/cs11196641812406231260.png
#   inflating: cartoonset10k/cs11197177838512744919.csv
#   inflating: cartoonset10k/cs11197177838512744919.png
#   inflating: cartoonset10k/cs11197587306742619467.csv
#   inflating: cartoonset10k/cs11197587306742619467.png
#   inflating: cartoonset10k/cs11197791988230855675.csv
#   inflating: cartoonset10k/cs11197791988230855675.png
#   inflating: cartoonset10k/cs11197868149964141088.csv
#   inflating: cartoonset10k/cs11197868149964141088.png
#   inflating: cartoonset10k/cs11197898205174058969.csv
#   inflating: cartoonset10k/cs11197898205174058969.png
#   inflating: cartoonset10k/cs11197899472381407160.csv
#   inflating: cartoonset10k/cs11197899472381407160.png
#   inflating: cartoonset10k/cs11197935779171696249.csv
# ...
#   inflating: cartoonset10k/cs11484153065716911216.csv
#   inflating: cartoonset10k/cs11484153065716911216.png
#   inflating: cartoonset10k/cs11484262654489067342.csv
#   inflating: cartoonset10k/cs11484262654489067342.png
#   inflating: cartoonset10k/cs1148437998554422423.csv
#   inflating: cartoonset10k/cs1148437998554422423.png
#   inflating: cartoonset10k/cs11484441146906606262.csv
#   inflating: cartoonset10k/cs11484441146906606262.png
#   inflating: cartoonset10k/cs11484555276782711821.csv
#   inflating: cartoonset10k/cs11484555276782711821.png
#   inflating: cartoonset10k/cs11484766413976672210.csv
#   inflating: cartoonset10k/cs11484766413976672210.png
#   inflating: cartoonset10k/cs11484879231101235655.csv
#   inflating: cartoonset10k/cs11484879231101235655.png
#   inflating: cartoonset10k/cs11484965662281874328.csv
#   inflating: cartoonset10k/cs11484965662281874328.png
#   inflating: cartoonset10k/cs11485081299535020301.csv
#   inflating: cartoonset10k/cs11485081299535020301.png
#   inflating: cartoonset10k/cs11485151431190426232.csv
#   inflating: cartoonset10k/cs11485151431190426232.png
#   inflating: cartoonset10k/cs11485157956132321610.csv
#   inflating: cartoonset10k/cs11485157956132321610.png
#   inflating: cartoonset10k/cs11485259187146357965.csv
#   inflating: cartoonset10k/cs11485259187146357965.png
#   inflating: cartoonset10k/cs11485347762486750275.csv
#   inflating: cartoonset10k/cs11485347762486750275.png
#   inflating: cartoonset10k/cs11485570648169229431.csv
#   inflating: cartoonset10k/cs11485570648169229431.png
#   inflating: cartoonset10k/cs11485905459498534104.csv
#   inflating: cartoonset10k/cs11485905459498534104.png
#   inflating: cartoonset10k/cs11486035871749593712.csv
#   inflating: cartoonset10k/cs11486035871749593712.png
#   inflating: cartoonset10k/cs11486795826949600448.csv
#   inflating: cartoonset10k/cs11486795826949600448.png
#   inflating: cartoonset10k/cs1148689028663625501.csv
#   inflating: cartoonset10k/cs1148689028663625501.png
#   inflating: cartoonset10k/cs11486938276460846311.csv
#   inflating: cartoonset10k/cs11486938276460846311.png
#   inflating: cartoonset10k/cs11486983642687637865.csv
#   inflating: cartoonset10k/cs11486983642687637865.png
#   inflating: cartoonset10k/cs11487038856963974796.csv
#   inflating: cartoonset10k/cs11487038856963974796.png
#   inflating: cartoonset10k/cs11487150332143131748.csv
#   inflating: cartoonset10k/cs11487150332143131748.png
#   inflating: cartoonset10k/cs11487391019496033465.csv
#   inflating: cartoonset10k/cs11487391019496033465.png
#   inflating: cartoonset10k/cs11487436051801617195.csv
#   inflating: cartoonset10k/cs11487436051801617195.png
#   inflating: cartoonset10k/cs11487444662787178674.csv
#   inflating: cartoonset10k/cs11487444662787178674.png
#   inflating: cartoonset10k/cs11487503071279498482.csv
#   inflating: cartoonset10k/cs11487503071279498482.png
#   inflating: cartoonset10k/cs11487713686860915466.csv
#   inflating: cartoonset10k/cs11487713686860915466.png
#   inflating: cartoonset10k/cs11487774922665056842.csv
#   inflating: cartoonset10k/cs11487774922665056842.png
#   inflating: cartoonset10k/cs1148795159431018636.csv
#   inflating: cartoonset10k/cs1148795159431018636.png
#   inflating: cartoonset10k/cs11488003623920352844.csv
#   inflating: cartoonset10k/cs11488003623920352844.png
#   inflating: cartoonset10k/cs11488131778965628135.csv
#   inflating: cartoonset10k/cs11488131778965628135.png
#   inflating: cartoonset10k/cs11488190083434308775.csv
#   inflating: cartoonset10k/cs11488190083434308775.png
#   inflating: cartoonset10k/cs11488264387237725197.csv
#   inflating: cartoonset10k/cs11488264387237725197.png
#   inflating: cartoonset10k/cs11488293396236871174.csv
#   inflating: cartoonset10k/cs11488293396236871174.png
#   inflating: cartoonset10k/cs1148847438501482075.csv
#   inflating: cartoonset10k/cs1148847438501482075.png
#   inflating: cartoonset10k/cs11488637628377837106.csv
#   inflating: cartoonset10k/cs11488637628377837106.png
#   inflating: cartoonset10k/cs11488823119089058534.csv
#   inflating: cartoonset10k/cs11488823119089058534.png
#   inflating: cartoonset10k/cs11488830939466242787.csv
#   inflating: cartoonset10k/cs11488830939466242787.png
#   inflating: cartoonset10k/cs11488846002088682819.csv
#   inflating: cartoonset10k/cs11488846002088682819.png
#   inflating: cartoonset10k/cs11488862443629084886.csv
#   inflating: cartoonset10k/cs11488862443629084886.png
#   inflating: cartoonset10k/cs11488929199701885958.csv
#   inflating: cartoonset10k/cs11488929199701885958.png
#   inflating: cartoonset10k/cs11489116904791641544.csv
#   inflating: cartoonset10k/cs11489116904791641544.png
#   inflating: cartoonset10k/cs11489158557218364289.csv
#   inflating: cartoonset10k/cs11489158557218364289.png
#   inflating: cartoonset10k/cs11489359689392658197.csv
#   inflating: cartoonset10k/cs11489359689392658197.png
#   inflating: cartoonset10k/cs11489609219964014064.csv
#   inflating: cartoonset10k/cs11489609219964014064.png
#   inflating: cartoonset10k/cs11489751240431094365.csv
#   inflating: cartoonset10k/cs11489751240431094365.png
#   inflating: cartoonset10k/cs1148989641954840258.csv
#   inflating: cartoonset10k/cs1148989641954840258.png
#   inflating: cartoonset10k/cs11490001629933040554.csv
#   inflating: cartoonset10k/cs11490001629933040554.png
#   inflating: cartoonset10k/cs11490002973990271424.csv
#   inflating: cartoonset10k/cs11490002973990271424.png
#   inflating: cartoonset10k/cs11490028718359837317.csv
#   inflating: cartoonset10k/cs11490028718359837317.png
#   inflating: cartoonset10k/cs11490154093081112909.csv
#   inflating: cartoonset10k/cs11490154093081112909.png
#   inflating: cartoonset10k/cs1149031106774046226.csv
#   inflating: cartoonset10k/cs1149031106774046226.png
#   inflating: cartoonset10k/cs11490418955467301369.csv
#   inflating: cartoonset10k/cs11490418955467301369.png
#   inflating: cartoonset10k/cs11490526003629686790.csv
#   inflating: cartoonset10k/cs11490526003629686790.png
#   inflating: cartoonset10k/cs11490600905468098235.csv
#   inflating: cartoonset10k/cs11490600905468098235.png
#   inflating: cartoonset10k/cs11490665013101380496.csv
#   inflating: cartoonset10k/cs11490665013101380496.png
#   inflating: cartoonset10k/cs11490678919913204331.csv
#   inflating: cartoonset10k/cs11490678919913204331.png
#   inflating: cartoonset10k/cs11490769198722832331.csv
#   inflating: cartoonset10k/cs11490769198722832331.png
#   inflating: cartoonset10k/cs11490801975691181575.csv
#   inflating: cartoonset10k/cs11490801975691181575.png
#   inflating: cartoonset10k/cs11490956359515281382.csv
#   inflating: cartoonset10k/cs11490956359515281382.png
#   inflating: cartoonset10k/cs11490988897064658610.csv
#   inflating: cartoonset10k/cs11490988897064658610.png
#   inflating: cartoonset10k/cs11491016944486648525.csv
#   inflating: cartoonset10k/cs11491016944486648525.png
#   inflating: cartoonset10k/cs11491035965371661742.csv
#   inflating: cartoonset10k/cs11491035965371661742.png
#   inflating: cartoonset10k/cs11491068623649134557.csv
#   inflating: cartoonset10k/cs11491068623649134557.png
#   inflating: cartoonset10k/cs11491368901710731995.csv
#   inflating: cartoonset10k/cs11491368901710731995.png
#   inflating: cartoonset10k/cs11491755297579324423.csv
#   inflating: cartoonset10k/cs11491755297579324423.png
#   inflating: cartoonset10k/cs11491793072939244878.csv
#   inflating: cartoonset10k/cs11491793072939244878.png
#   inflating: cartoonset10k/cs11492088934945302376.csv
#   inflating: cartoonset10k/cs11492088934945302376.png
#   inflating: cartoonset10k/cs11492130651405143660.csv
#   inflating: cartoonset10k/cs11492130651405143660.png
#   inflating: cartoonset10k/cs11492467954175630468.csv
#   inflating: cartoonset10k/cs11492467954175630468.png
#   inflating: cartoonset10k/cs11492545430398134004.csv
#   inflating: cartoonset10k/cs11492545430398134004.png
#   inflating: cartoonset10k/cs11492728441529230880.csv
#   inflating: cartoonset10k/cs11492728441529230880.png
#   inflating: cartoonset10k/cs11492730034791037525.csv
#   inflating: cartoonset10k/cs11492730034791037525.png
#   inflating: cartoonset10k/cs11493049696035072013.csv
#   inflating: cartoonset10k/cs11493049696035072013.png
#   inflating: cartoonset10k/cs11493116805149717397.csv
#   inflating: cartoonset10k/cs11493116805149717397.png
#   inflating: cartoonset10k/cs11493180956272986183.csv
#   inflating: cartoonset10k/cs11493180956272986183.png
#   inflating: cartoonset10k/cs11493511398876547269.csv
#   inflating: cartoonset10k/cs11493511398876547269.png
#   inflating: cartoonset10k/cs11493771563561876418.csv
#   inflating: cartoonset10k/cs11493771563561876418.png
#   inflating: cartoonset10k/cs11493913978118837551.csv
#   inflating: cartoonset10k/cs11493913978118837551.png
#   inflating: cartoonset10k/cs1149399331195862334.csv
#   inflating: cartoonset10k/cs1149399331195862334.png
#   inflating: cartoonset10k/cs11494124046679989034.csv
#   inflating: cartoonset10k/cs11494124046679989034.png
#   inflating: cartoonset10k/cs1149416823664533049.csv
#   inflating: cartoonset10k/cs1149416823664533049.png
#   inflating: cartoonset10k/cs11494224178439186741.csv
#   inflating: cartoonset10k/cs11494224178439186741.png
#   inflating: cartoonset10k/cs11494233981598861698.csv
#   inflating: cartoonset10k/cs11494233981598861698.png
#   inflating: cartoonset10k/cs11494349241863383876.csv
#   inflating: cartoonset10k/cs11494349241863383876.png
#   inflating: cartoonset10k/cs1149440047435617496.csv
#   inflating: cartoonset10k/cs1149440047435617496.png
#   inflating: cartoonset10k/cs11494439060570961709.csv
#   inflating: cartoonset10k/cs11494439060570961709.png
#   inflating: cartoonset10k/cs11494647291641456385.csv
#   inflating: cartoonset10k/cs11494647291641456385.png
#   inflating: cartoonset10k/cs11494657127895636130.csv
#   inflating: cartoonset10k/cs11494657127895636130.png
#   inflating: cartoonset10k/cs11494810152956454974.csv
#   inflating: cartoonset10k/cs11494810152956454974.png
#   inflating: cartoonset10k/cs11494817298029858308.csv
#   inflating: cartoonset10k/cs11494817298029858308.png
#   inflating: cartoonset10k/cs11494975883518888609.csv
#   inflating: cartoonset10k/cs11494975883518888609.png
#   inflating: cartoonset10k/cs11495134076688581941.csv
#   inflating: cartoonset10k/cs11495134076688581941.png
#   inflating: cartoonset10k/cs11495360358246107794.csv
#   inflating: cartoonset10k/cs11495360358246107794.png
#   inflating: cartoonset10k/cs1149547913216701267.csv
#   inflating: cartoonset10k/cs1149547913216701267.png
#   inflating: cartoonset10k/cs11495518007934695978.csv
#   inflating: cartoonset10k/cs11495518007934695978.png
#   inflating: cartoonset10k/cs11495632956884475775.csv
#   inflating: cartoonset10k/cs11495632956884475775.png
#   inflating: cartoonset10k/cs11495697248149400024.csv
#   inflating: cartoonset10k/cs11495697248149400024.png
#   inflating: cartoonset10k/cs11495831527740017327.csv
#   inflating: cartoonset10k/cs11495831527740017327.png
#   inflating: cartoonset10k/cs11495836560644161391.csv
#   inflating: cartoonset10k/cs11495836560644161391.png
#   inflating: cartoonset10k/cs11495879286937280061.csv
#   inflating: cartoonset10k/cs11495879286937280061.png
#   inflating: cartoonset10k/cs11496008407922752635.csv
#   inflating: cartoonset10k/cs11496008407922752635.png
#   inflating: cartoonset10k/cs11496205076399804612.csv
#   inflating: cartoonset10k/cs11496205076399804612.png
#   inflating: cartoonset10k/cs11496249579948065035.csv
#   inflating: cartoonset10k/cs11496249579948065035.png
#   inflating: cartoonset10k/cs11496260998108803221.csv
#   inflating: cartoonset10k/cs11496260998108803221.png
#   inflating: cartoonset10k/cs11496285006672394132.csv
#   inflating: cartoonset10k/cs11496285006672394132.png
#   inflating: cartoonset10k/cs1149648339250881314.csv
#   inflating: cartoonset10k/cs1149648339250881314.png
#   inflating: cartoonset10k/cs11496613784648179444.csv
#   inflating: cartoonset10k/cs11496613784648179444.png
#   inflating: cartoonset10k/cs11496716266500352787.csv
#   inflating: cartoonset10k/cs11496716266500352787.png
#   inflating: cartoonset10k/cs11496839623386988994.csv
#   inflating: cartoonset10k/cs11496839623386988994.png
#   inflating: cartoonset10k/cs11497077681490484507.csv
#   inflating: cartoonset10k/cs11497077681490484507.png
#   inflating: cartoonset10k/cs11497746939268723984.csv
#   inflating: cartoonset10k/cs11497746939268723984.png
#   inflating: cartoonset10k/cs11497822572512405506.csv
#   inflating: cartoonset10k/cs11497822572512405506.png
#   inflating: cartoonset10k/cs11497879765990689461.csv
#   inflating: cartoonset10k/cs11497879765990689461.png
#   inflating: cartoonset10k/cs11497974948794603242.csv
#   inflating: cartoonset10k/cs11497974948794603242.png
#   inflating: cartoonset10k/cs11498542177707458348.csv
#   inflating: cartoonset10k/cs11498542177707458348.png
#   inflating: cartoonset10k/cs11498563727420151760.csv
#   inflating: cartoonset10k/cs11498563727420151760.png
#   inflating: cartoonset10k/cs1149858768437496562.csv
#   inflating: cartoonset10k/cs1149858768437496562.png
#   inflating: cartoonset10k/cs11498797650555228902.csv
#   inflating: cartoonset10k/cs11498797650555228902.png
#   inflating: cartoonset10k/cs11498939292983011494.csv
#   inflating: cartoonset10k/cs11498939292983011494.png
#   inflating: cartoonset10k/cs11499087112014290850.csv
#   inflating: cartoonset10k/cs11499087112014290850.png
#   inflating: cartoonset10k/cs11499177954530050406.csv
#   inflating: cartoonset10k/cs11499177954530050406.png
#   inflating: cartoonset10k/cs11499191039966685427.csv
#   inflating: cartoonset10k/cs11499191039966685427.png
#   inflating: cartoonset10k/cs11499277167058022577.csv
#   inflating: cartoonset10k/cs11499277167058022577.png
#   inflating: cartoonset10k/cs11499318732890731121.csv
#   inflating: cartoonset10k/cs11499318732890731121.png
#   inflating: cartoonset10k/cs11499323325775509736.csv
#   inflating: cartoonset10k/cs11499323325775509736.png
#   inflating: cartoonset10k/cs11499684480178852318.csv
#   inflating: cartoonset10k/cs11499684480178852318.png
#   inflating: cartoonset10k/cs11499751129990567206.csv
#   inflating: cartoonset10k/cs11499751129990567206.png
#   inflating: cartoonset10k/cs11499805444367164452.csv
#   inflating: cartoonset10k/cs11499805444367164452.png
#   inflating: cartoonset10k/cs11499959365834285203.csv
#   inflating: cartoonset10k/cs11499959365834285203.png
#   inflating: cartoonset10k/cs11500463050250299821.csv
#   inflating: cartoonset10k/cs11500463050250299821.png
#   inflating: cartoonset10k/cs11500552060848520510.csv
#   inflating: cartoonset10k/cs11500552060848520510.png
#   inflating: cartoonset10k/cs11500615792753390050.csv
#   inflating: cartoonset10k/cs11500615792753390050.png
#   inflating: cartoonset10k/cs11500768489142118159.csv
#   inflating: cartoonset10k/cs11500768489142118159.png
#   inflating: cartoonset10k/cs11500850459732791478.csv
#   inflating: cartoonset10k/cs11500850459732791478.png
#   inflating: cartoonset10k/cs11501318948920968198.csv
#   inflating: cartoonset10k/cs11501318948920968198.png
#   inflating: cartoonset10k/cs11501385337001567920.csv
#   inflating: cartoonset10k/cs11501385337001567920.png
#   inflating: cartoonset10k/cs115015743350173470.csv
#   inflating: cartoonset10k/cs115015743350173470.png
#   inflating: cartoonset10k/cs11501642145622483224.csv
#   inflating: cartoonset10k/cs11501642145622483224.png
#   inflating: cartoonset10k/cs11501710450116498461.csv
#   inflating: cartoonset10k/cs11501710450116498461.png
#   inflating: cartoonset10k/cs11501903618553236910.csv
#   inflating: cartoonset10k/cs11501903618553236910.png
#   inflating: cartoonset10k/cs11501908823197889107.csv
#   inflating: cartoonset10k/cs11501908823197889107.png
#   inflating: cartoonset10k/cs11501981190804367864.csv
#   inflating: cartoonset10k/cs11501981190804367864.png

# %%
import os, time

import numpy as np
from PIL import Image
from tqdm import tqdm
import matplotlib.pyplot as plt
from IPython import display

import tensorflow as tf
from tensorflow.keras.layers import Input, Reshape, Dropout, Dense
from tensorflow.keras.layers import Flatten, BatchNormalization
from tensorflow.keras.layers import Activation, ZeroPadding2D
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.layers import UpSampling2D, Conv2D, Conv2DTranspose
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.optimizers import Adam

# %%
def hms_string(sec_elapsed):
    h = int(sec_elapsed / (60 * 60))
    m = int((sec_elapsed % (60 * 60)) / 60)
    s = sec_elapsed % 60
    return "{}:{:>02}:{:>05.2f}".format(h, m, s)

# %%
IMAGE_CHANNELS = 3
GENERATE_RESOLUTION_FACTOR = 3
GENERATE_SQUARE = 32 * GENERATE_RESOLUTION_FACTOR

# Preview image details
PREVIEW_ROWS, PREVIEW_COLS = 4, 7
PREVIEW_MARGIN = 16

# Source vector size to generate images
SEED_SIZE = 100

# Model configuration
DATA_PATH = '/content/cartoonset10k'
FOLDER_NAME = 'cartoonset10k'

EPOCHS = 50
BATCH_SIZE = 64
BUFFER_SIZE = 61000

print(f"Image details: {GENERATE_SQUARE}px")
# Out:
# Image details: 96px

# %%
training_binary_path = os.path.join(DATA_PATH,
    f'training_data_{GENERATE_SQUARE}_{GENERATE_SQUARE}.npy')
print("Binary file name: ", training_binary_path)

if not os.path.isfile(training_binary_path):
  start = time.time()
  print("File not found, loading training images...")

  training_data = []
  faces_path = DATA_PATH
  faces_path_filenames = os.listdir(faces_path)
  for filename in tqdm(faces_path_filenames):
      path = os.path.join(faces_path,filename)
      # Convert RGBA to RGB format
      try:
        image = Image.open(path).convert("RGB").resize((GENERATE_SQUARE,
              GENERATE_SQUARE),Image.ANTIALIAS)
        training_data.append(np.asarray(image))
      except Exception as e:
        # print(f'[Error] image: {image}, exception: {e}')
        pass
  training_data = np.reshape(training_data,(-1,GENERATE_SQUARE,
            GENERATE_SQUARE,IMAGE_CHANNELS))
  training_data = training_data.astype(np.float32)
  training_data = training_data / 127.5 - 1.


  print("Saving training image binary file...")
  np.save(training_binary_path,training_data)
  stop = time.time()-start
  print (f'Image preprocess time: {hms_string(stop)}')
else:
  print("Loading previous training binary file...")
  load_data_start_time = time.time()
  training_data = np.load(training_binary_path)
  load_data_tat = time.time() - load_data_start_time
  print("Data load time: ", hms_string(load_data_tat))
# Out:
# Binary file name:  /content/cartoonset10k/training_data_96_96.npy
# File not found, loading training images...
#   0%|          | 0/20000 [00:00<?, ?it/s]<ipython-input-5-8fe200ba2d21>:17: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   GENERATE_SQUARE),Image.ANTIALIAS)
# 100%|██████████| 20000/20000 [01:38<00:00, 202.33it/s]
# Saving training image binary file...
# Image preprocess time: 0:01:44.72

# %%
train_dataset = tf.data.Dataset.from_tensor_slices(training_data).shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
print("Length of total images: ", len(training_data))
print("Length of total batches: ", len(train_dataset))
print("Length of images in one batch: ", len(list(train_dataset.as_numpy_iterator())[0]))
# Out:
# Length of total images:  10000
# Length of total batches:  157
# Length of images in one batch:  64

# %%
def build_generator(seed_size, channels):
  model = Sequential()

  model.add(Dense(4*4*256,activation="relu",input_dim=seed_size))
  model.add(BatchNormalization())
  model.add(LeakyReLU())
  model.add(Reshape((4, 4, 256)))

  model.add(Conv2DTranspose(256, (5, 5), strides=(2, 2), padding='same', use_bias=False))
  assert model.output_shape == (None, 8, 8, 256)
  model.add(BatchNormalization())
  model.add(LeakyReLU())

  model.add(Conv2DTranspose(256, (5, 5), strides=(2, 2), padding='same', use_bias=False))
  assert model.output_shape == (None, 16, 16, 256)
  model.add(BatchNormalization())
  model.add(LeakyReLU())


  model.add(Conv2DTranspose(256, (5, 5), strides=(2, 2), padding='same', use_bias=False, activation='tanh'))
  assert model.output_shape == (None, 32, 32, 256)
  model.add(BatchNormalization())
  model.add(LeakyReLU())


  model.add(Conv2DTranspose(64, (5, 5), strides=(3, 3), padding='same', use_bias=False, activation='tanh'))
  assert model.output_shape == (None, 96, 96, 64)
  model.add(BatchNormalization())
  model.add(LeakyReLU())

  model.add(Conv2DTranspose(3, (5, 5), strides=(1, 1), padding='same', use_bias=False, activation='tanh'))
  assert model.output_shape == (None, 96, 96, 3)

  return model

# %%
def build_discriminator(image_shape):
    model = Sequential()

    model.add(Conv2D(32, kernel_size=3, strides=2, input_shape=image_shape,
                     padding="same"))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.2))
    model.add(Conv2D(64, kernel_size=3, strides=2, padding="same"))
    model.add(ZeroPadding2D(padding=((0,1),(0,1))))
    model.add(BatchNormalization(momentum=0.7))
    model.add(LeakyReLU(alpha=0.3))

    model.add(Dropout(0.2))
    model.add(Conv2D(128, kernel_size=3, strides=2, padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.2))
    model.add(Conv2D(256, kernel_size=3, strides=1, padding="same"))
    model.add(BatchNormalization(momentum=0.7))
    model.add(LeakyReLU(alpha=0.3))

    model.add(Dropout(0.2))
    model.add(Conv2D(512, kernel_size=3, strides=1, padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.2))
    model.add(Flatten())
    model.add(Dense(1, activation='sigmoid'))

    return model

# %%
def save_images(cnt,noise):
  image_array = np.full((
      PREVIEW_MARGIN + (PREVIEW_ROWS * (GENERATE_SQUARE+PREVIEW_MARGIN)),
      PREVIEW_MARGIN + (PREVIEW_COLS * (GENERATE_SQUARE+PREVIEW_MARGIN)), 3),
      255, dtype=np.uint8)

  generated_images = generator.predict(noise)

  generated_images = 0.5 * generated_images + 0.5

  image_count = 0
  for row in range(PREVIEW_ROWS):
      for col in range(PREVIEW_COLS):
        r = row * (GENERATE_SQUARE+16) + PREVIEW_MARGIN
        c = col * (GENERATE_SQUARE+16) + PREVIEW_MARGIN
        image_array[r:r+GENERATE_SQUARE,c:c+GENERATE_SQUARE] \
            = generated_images[image_count] * 255
        image_count += 1


  output_path = os.path.join(DATA_PATH,'output')
  if not os.path.exists(output_path):
    os.makedirs(output_path)

  filename = os.path.join(output_path,f"train-{cnt}.png")
  im = Image.fromarray(image_array)

  fig = plt.figure(figsize=(15,15))
  plt.imshow(im)
  plt.show()
  im.save(filename)

# %%
generator = build_generator(SEED_SIZE, IMAGE_CHANNELS)

noise = tf.random.normal([1, SEED_SIZE])
generated_image = generator(noise, training=False)
print("Generated image shape: ", generated_image.shape)

plt.imshow(generated_image[0, :, :, 0])
# Out:
# Generated image shape:  (1, 96, 96, 3)

# %%
image_shape = (GENERATE_SQUARE,GENERATE_SQUARE,IMAGE_CHANNELS)

discriminator = build_discriminator(image_shape)
decision = discriminator(generated_image)
print (decision)
# Out:
# tf.Tensor([[0.4999671]], shape=(1, 1), dtype=float32)

# %%
# This method returns a helper function to compute cross entropy loss
cross_entropy = tf.keras.losses.BinaryCrossentropy()

def discriminator_loss(real_output, fake_output):
    real_loss = cross_entropy(tf.ones_like(real_output), real_output)
    fake_loss = cross_entropy(tf.zeros_like(fake_output), fake_output)
    total_loss = real_loss + fake_loss
    return total_loss

def generator_loss(fake_output):
    return cross_entropy(tf.ones_like(fake_output), fake_output)

# %%
generator_optimizer = tf.keras.optimizers.Adam(1.5e-4,0.5)
discriminator_optimizer = tf.keras.optimizers.Adam(1.5e-4,0.5)

# %%
@tf.function
def train_step(images):
  seed = tf.random.normal([BATCH_SIZE, SEED_SIZE])

  with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
    generated_images = generator(seed, training=True)

    real_output = discriminator(images, training=True)
    fake_output = discriminator(generated_images, training=True)

    gen_loss = generator_loss(fake_output)
    disc_loss = discriminator_loss(real_output, fake_output)


    gradients_of_generator = gen_tape.gradient(\
        gen_loss, generator.trainable_variables)
    gradients_of_discriminator = disc_tape.gradient(\
        disc_loss, discriminator.trainable_variables)

    generator_optimizer.apply_gradients(zip(
        gradients_of_generator, generator.trainable_variables))
    discriminator_optimizer.apply_gradients(zip(
        gradients_of_discriminator,
        discriminator.trainable_variables))
  # generate_and_save_images(generator, epochs, seed)
  return gen_loss,disc_loss

# %%
def generate_and_save_images(model, epoch, test_input):
  # Notice `training` is set to False.
  # This is so all layers run in inference mode (batchnorm).
  predictions = model(test_input, training=False)

  fig = plt.figure(figsize=(4,4))

  for i in range(predictions.shape[0]):
      plt.subplot(4, 4, i+1)
      plt.imshow(predictions[i, :, :, 0] * 127.5 + 127.5, cmap='gray')
      plt.axis('off')

  plt.savefig('image_at_epoch_{:04d}.png'.format(epoch))
  plt.show()

# %%
def train(dataset, epochs):
  fixed_seed = np.random.normal(0, 1, (PREVIEW_ROWS * PREVIEW_COLS,
                                       SEED_SIZE))
  start = time.time()

  for epoch in range(epochs):
    epoch_start = time.time()

    gen_loss_list = []
    disc_loss_list = []

    for image_batch in dataset:
      t = train_step(image_batch)
      gen_loss_list.append(t[0])
      disc_loss_list.append(t[1])

    g_loss = sum(gen_loss_list) / len(gen_loss_list)
    d_loss = sum(disc_loss_list) / len(disc_loss_list)

    epoch_elapsed = time.time()-epoch_start
    print (f'Epoch {epoch+1}, gen loss={g_loss},disc loss={d_loss}, time={hms_string(epoch_elapsed)}')

    display.clear_output(wait=True)
    print (f'Epoch {epoch+1}, gen loss={g_loss},disc loss={d_loss}, time={hms_string(epoch_elapsed)}')
    save_images(epoch,fixed_seed)

  display.clear_output(wait=True)
  print (f'Epoch {epoch+1}, gen loss={g_loss},disc loss={d_loss}, time={hms_string(epoch_elapsed)}')
  save_images(epoch,fixed_seed)

  elapsed = time.time()-start
  print (f'Training time: {hms_string(elapsed)}')

# %%
train(train_dataset, EPOCHS)
# Out:
# Epoch 50, gen loss=4.558496475219727,disc loss=0.4428933560848236, time=0:00:39.18
# 1/1 [==============================] - 0s 20ms/step
# Training time: 0:33:40.64

# %%
name = f"face_generator_{EPOCHS}.h5"
generator.save(os.path.join(DATA_PATH, name))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
